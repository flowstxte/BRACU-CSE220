# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def postorder(root):
  if root == None:
    return

  postorder(root.left)
  postorder(root.right)
  print(root.elem, end = ' ')

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  if root==None:
    return
  root.left,root.right=root.right,root.left
  convert_mirror(root.left)
  convert_mirror(root.right)
  return root

#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root):
  if root==None:
    return {}
  d={}
  def temp(r,i=0):
    if r!=None:
      if i not in d:
        d[i]=r.elem
      else:
        if r.elem<d[i]:
          d[i]=r.elem
      temp(r.left,i+1)
      temp(r.right,i+1)
    else:
      return None
  temp(root)
  return d


#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def maximum(x):
  while x.right!=None:
    x=x.right
  return x

def inorder_predecessor(root, x):
  if x.left!=None:
    return maximum(x.left)
  r=None
  while root!=None:
    if x.elem>root.elem:
      r=root
      root=root.right
    else:
       root=root.left
  return r

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = n5
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 10: 8

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
  if root==None:
    return None
  if root.elem>x and root.elem>y:
    return LCA(root.left,x,y)
  if root.elem<x and root.elem<y:
    return LCA(root.right,x,y)
  return root.elem

#DRIVER CODE
#Write by yourself from the given tree
#check all the sample inputs given

root=tree_construction([None, 15, 10, 25, 8, 12, 20, 30, 6, 9, None, None, 18, 22])

print("LCA(6,12) =",LCA(root,6,12))
print("LCA(20,6) =",LCA(root,20,6))
print("LCA(18,22) =",LCA(root,18,22))
print("LCA(20,25) =",LCA(root,20,25))
print("LCA(10,12) =",LCA(root,10,12))
# Out:
# LCA(6,12) = 10
# LCA(20,6) = 15
# LCA(18,22) = 20
# LCA(20,25) = 25
# LCA(10,12) = 10

# %% [markdown]
# BONUS TASK 1

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF
def SumSubTree(r):
  if r==None:
    return 0
  return SumSubTree(r.left)+r.elem+SumSubTree(r.right)
def SumTree(r):
  if r==None:
    return True
  if r.left==None and r.right==None:
    return True
  lsum=SumSubTree(r.left)
  rsum = SumSubTree(r.right)
  if r.elem==lsum+rsum and SumTree(r.left) and SumTree(r.right):
    return True
  return False

root=BTNode(26)
n10=BTNode(10)
n3=BTNode(3)
n4=BTNode(4)
n6=BTNode(6)
n3x=BTNode(3)
root.left=n10
root.right=n3
n10.left=n4
n10.right=n6
n3.right=n3x
print(SumTree(root))
# Out:
# True

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF
def TreeDifference(r,i=0):
  if r==None:
    return 0
  if i%2!=0:
    return r.elem+TreeDifference(r.left,i+1)+TreeDifference(r.right,i+1)
  else:
    return -r.elem+TreeDifference(r.left,i+1)+TreeDifference(r.right,i+1)
#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8

print(TreeDifference(root))
# Out:
# 4
